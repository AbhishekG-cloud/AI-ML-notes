# %%
## SELECTION SORT 
def sel_sor(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i+1,n):
            if arr[min_index] > arr[j]:
                min_index = j
        arr[i],arr[min_index] = arr[min_index],arr[i]
    return arr
arr = [13,5,78,98,67,14,0]
sel_sor(arr)
# Out:
# [0, 5, 13, 14, 67, 78, 98]

# %%
## BUBBLE SORT
def bub_sor(arr):
    n = len(arr)
    for _ in range(n):
        for i in range(n-1):
            if arr[i] >arr[i+1]:
                arr[i],arr[i+1] = arr[i+1],arr[i]
    
    return arr
arr = [13,5,78,98,67,14,0]
bub_sor(arr)
# Out:
# [0, 5, 13, 14, 67, 78, 98]

# %%
##INSERTION SORT
def insertion_sort(arr):
    n = len(arr)

    for i in range(1, n):
        key = arr[i]  # element to insert
        j = i - 1

        # shift elements greater than key
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        # place key at correct position
        arr[j + 1] = key

    return arr

# %%
## MERGE SORTING
def merge_sort(arr):
    if len(arr)<=1:
        return arr
    mid = len(arr)//2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left,right)

def merge(left,right):
    i=j=0
    result = []
    while i<len(left) and j<len(right):
        if left[i] > right[j]:
            result.append(right[j])
            j+=1
        else:
            result.append(left[i])
            i+=1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

arr = [13,5,78,98,67,14,0]
print(merge_sort(arr))
# Out:
# [0, 5, 13, 14, 67, 78, 98]

# %%
## RECURSIVE BUBBLE SORT
def rec_bub_sort(arr,n):
    if n==1:
        return arr
    
    for i in range(n-1):
        if arr[i] > arr[i+1]:
            arr[i],arr[i+1] = arr[i+1],arr[i]
    rec_bub_sort(arr,n-1)
arr = [13,5,78,98,67,14,0]
print(rec_bub_sort(arr,len(arr)))
print(arr)
# Out:
# None
# [0, 5, 13, 14, 67, 78, 98]

# %%
## RECURSIVE INSERTION SORT
def recursive_insertion_sort(arr, n):

    # base case
    if n <= 1:
        return

    # sort first n-1 elements
    recursive_insertion_sort(arr, n - 1)

    # insert last element at correct position
    last = arr[n - 1]
    j = n - 2

    # shift larger elements
    while j >= 0 and arr[j] > last:
        arr[j + 1] = arr[j]
        j -= 1

    arr[j + 1] = last


# example
arr = [5, 2, 4, 6, 1]

recursive_insertion_sort(arr, len(arr))

print(arr)

# %%
## QUICK SORT
def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1
    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            # swap smaller element to left side
            arr[i], arr[j] = arr[j], arr[i]
    # place pivot at correct position
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

def quick_sort(arr, low, high):
    if low < high:
        # partition index
        pi = partition(arr, low, high)
        # sort left part
        quick_sort(arr, low, pi - 1)
        # sort right part
        quick_sort(arr, pi + 1, high)

arr = [8, 3, 1, 7, 0, 10, 2]
quick_sort(arr, 0, len(arr) - 1)
print(arr)

# %%
arr = [1,2,3,4,5,6,7]
def left_rot(arr):
    a= arr[0]
    new = arr[1:]
    new.append(a)
    return new 
print(left_rot(arr))
# Out:
# [2, 3, 4, 5, 6, 7, 1]

# %%
arr = [1,2,3,4,5,6,7]
def left_rot_k(arr,k):
    a= arr[0:k]
    new = arr[k:]
    new.extend(a)
    return new 
print(left_rot_k(arr,5))
# Out:
# [6, 7, 1, 2, 3, 4, 5]
