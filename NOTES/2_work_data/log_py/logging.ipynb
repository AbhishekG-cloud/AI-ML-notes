# %%
# logging to keep track of events, errors,and operational information.

# %%
import logging

# Configure logging
logging.basicConfig(level=logging.INFO)

# Example logs
logging.debug("This is a DEBUG message")   # For debugging
logging.info("This is an INFO message")    # General info
logging.warning("This is a WARNING message")  # Warnings
logging.error("This is an ERROR message")  # Errors
logging.critical("This is a CRITICAL message")  # Critical issue
# Out:
# DEBUG:root:This is a DEBUG message
# INFO:root:This is an INFO message
# WARNING:root:This is a WARNING message
# ERROR:root:This is an ERROR message
# CRITICAL:root:This is a CRITICAL message

# %%
## configure logging
import logging
logging.basicConfig(
    filename="app.log",
    filemode="w",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    force=True
)
logging.debug("This is a DEBUG message")   # For debugging
logging.info("This is an INFO message")    # General info
logging.warning("This is a WARNING message")  # Warnings
logging.error("This is an ERROR message")  # Errors
logging.critical("This is a CRITICAL message")

# %%
logging.debug("This is a DEBUG message")   # For debugging
logging.info("This is an INFO message")    # General info
logging.warning("This is a WARNING message")  # Warnings
logging.error("This is an ERROR message")  # Errors
logging.critical("This is a CRITICAL message")
